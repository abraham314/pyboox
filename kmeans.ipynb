# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data=make_blobs(n_samples=200,n_features=2,centers=8,cluster_std=1.8,random_state=101)

# %%
data[0].shape
# Out:
# (200, 2)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=8, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-4.07673748,  8.10391969],
#        [ 3.80124854, -6.2481309 ],
#        [-9.53956213, -6.35476177],
#        [ 3.85048114,  6.9229514 ],
#        [-7.11377203,  5.1066263 ],
#        [ 9.21744249, -5.63273794],
#        [-0.52089468,  3.46279287],
#        [ 1.09547647, -1.36470749]])

# %%
kmeans.labels_
# Out:
# array([0, 1, 1, 1, 7, 5, 0, 5, 2, 2, 5, 2, 0, 7, 7, 0, 6, 4, 3, 1, 2, 3, 7,
#        7, 0, 7, 6, 6, 4, 7, 5, 4, 2, 6, 0, 7, 0, 0, 2, 3, 6, 7, 2, 5, 7, 0,
#        7, 7, 2, 2, 1, 6, 3, 6, 7, 2, 1, 6, 5, 1, 1, 0, 5, 3, 5, 7, 2, 2, 3,
#        4, 1, 1, 7, 4, 5, 3, 5, 5, 5, 2, 0, 0, 6, 1, 4, 7, 0, 3, 4, 3, 1, 7,
#        7, 2, 5, 6, 2, 7, 1, 5, 1, 3, 1, 6, 2, 6, 5, 5, 3, 3, 4, 3, 0, 1, 5,
#        2, 3, 4, 4, 3, 7, 4, 2, 3, 6, 2, 4, 2, 0, 0, 5, 5, 2, 5, 7, 3, 0, 4,
#        0, 7, 4, 0, 6, 5, 4, 1, 1, 2, 6, 1, 3, 4, 5, 1, 2, 3, 5, 5, 0, 5, 6,
#        7, 2, 4, 4, 1, 7, 0, 7, 2, 1, 6, 2, 0, 3, 6, 6, 7, 0, 4, 6, 7, 6, 3,
#        1, 6, 6, 1, 7, 0, 7, 5, 5, 4, 3, 3, 5, 3, 0, 3])

# %%
fig,(ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

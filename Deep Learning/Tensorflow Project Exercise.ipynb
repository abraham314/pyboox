# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Tensorflow Project
# Let's wrap up this Deep Learning by taking a a quick look at the effectiveness of Neural Nets!
#
# We'll use the [Bank Authentication Data Set](https://archive.ics.uci.edu/ml/datasets/banknote+authentication) from the UCI repository.
#
# The data consists of 5 columns:
#
# * variance of Wavelet Transformed image (continuous)
# * skewness of Wavelet Transformed image (continuous)
# * curtosis of Wavelet Transformed image (continuous)
# * entropy of image (continuous)
# * class (integer)
#
# Where class indicates whether or not a Bank Note was authentic.
#
# This sort of task is perfectly suited for Neural Networks and Deep Learning! Just follow the instructions below to get started!

# %% [markdown]
# ## Get the Data
#
# ** Use pandas to read in the bank_note_data.csv file **

# %%
import pandas as pd

# %%
bank=pd.read_csv('bank_note_data.csv')
bank.head()
# Out:
#    Image.Var  Image.Skew  Image.Curt  Entropy  Class
# 0    3.62160      8.6661     -2.8073 -0.44699      0
# 1    4.54590      8.1674     -2.4586 -1.46210      0
# 2    3.86600     -2.6383      1.9242  0.10645      0
# 3    3.45660      9.5228     -4.0112 -3.59440      0
# 4    0.32924     -4.4552      4.5718 -0.98880      0

# %% [markdown]
# ** Check the head of the Data **

# %%
# Out:
#    Image.Var  Image.Skew  Image.Curt  Entropy  Class
# 0    3.62160      8.6661     -2.8073 -0.44699      0
# 1    4.54590      8.1674     -2.4586 -1.46210      0
# 2    3.86600     -2.6383      1.9242  0.10645      0
# 3    3.45660      9.5228     -4.0112 -3.59440      0
# 4    0.32924     -4.4552      4.5718 -0.98880      0

# %% [markdown]
# ## EDA
#
# We'll just do a few quick plots of the data.
#
# ** Import seaborn and set matplolib inline for viewing **

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ** Create a Countplot of the Classes (Authentic 1 vs Fake 0) **

# %%
sns.countplot(x='Class',data=bank)

# %% [markdown]
# ** Create a PairPlot of the Data with Seaborn, set Hue to Class **

# %%
sns.pairplot(bank,hue='Class')

# %% [markdown]
# ## Data Preparation
#
# When using Neural Network and Deep Learning based systems, it is usually a good idea to Standardize your data, this step isn't actually necessary for our particular data set, but let's run through it for practice!
#
# ### Standard Scaling
#
# ** Import StandardScaler() from SciKit Learn**

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Create a StandardScaler() object called scaler.**

# %%
scaler=StandardScaler()

# %% [markdown]
# **Fit scaler to the features.**

# %%
scaler = StandardScaler()
scaler.fit(bank.drop('Class',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %% [markdown]
# **Use the .transform() method to transform the features to a scaled version.**

# %%
scaled_features = scaler.fit_transform(bank.drop('Class',axis=1))
scaled_f=pd.DataFrame(scaled_features,columns=bank.columns[:-1])
scaled_f.head()
# Out:
#    Image.Var  Image.Skew  Image.Curt   Entropy
# 0   1.121806    1.149455   -0.975970  0.354561
# 1   1.447066    1.064453   -0.895036 -0.128767
# 2   1.207810   -0.777352    0.122218  0.618073
# 3   1.063742    1.295478   -1.255397 -1.144029
# 4  -0.036772   -1.087038    0.736730  0.096587

# %% [markdown]
# **Convert the scaled features to a dataframe and check the head of this dataframe to make sure the scaling worked.**

# %%
# Out:
#    Image.Var  Image.Skew  Image.Curt   Entropy
# 0   1.121806    1.149455   -0.975970  0.354561
# 1   1.447066    1.064453   -0.895036 -0.128767
# 2   1.207810   -0.777352    0.122218  0.618073
# 3   1.063742    1.295478   -1.255397 -1.144029
# 4  -0.036772   -1.087038    0.736730  0.096587

# %% [markdown]
# ## Train Test Split
#
# ** Create two objects X and y which are the scaled feature values and labels respectively.**

# %%
from sklearn.cross_validation import train_test_split
# Out:
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X=scaled_f
y=bank['Class']

# %% [markdown]
# ** Use the .as_matrix() method on X and Y and reset them equal to this result. We need to do this in order for TensorFlow to accept the data in Numpy array form instead of a pandas series. **

# %%
X=X.as_matrix()
y=y.as_matrix()

# %% [markdown]
# ** Use SciKit Learn to create training and testing sets of the data as we've done in previous lectures:**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %% [markdown]
# # Contrib.learn
#
# ** Import tensorflow.contrib.learn.python.learn as learn**

# %%
import tensorflow.contrib.learn.python.learn as learn

# %% [markdown]
# ** Create an object called classifier which is a DNNClassifier from learn. Set it to have 2 classes and a [10,20,10] hidden unit layer structure:**

# %%
classifier = learn.DNNClassifier(hidden_units=[10, 20, 10], n_classes=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-0273d6847e2b> in <module>()
# ----> 1 classifier = learn.DNNClassifier(hidden_units=[10, 20, 10], n_classes=2)
#
# TypeError: __init__() missing 1 required positional argument: 'feature_columns'

# %% [markdown]
# ** Now fit classifier to the training data. Use steps=200 with a batch_size of 20. You can play around with these values if you want!**
#
# *Note: Ignore any warnings you get, they won't effect your output*

# %%
classifier.fit(X_train, y_train, steps=200, batch_size=20)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given features: Tensor("input:0", shape=(?, 4), dtype=float64), required signatures: TensorSignature(dtype=tf.float64, shape=TensorShape([Dimension(None), Dimension(4)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# WARNING:tensorflow:Given targets: Tensor("output:0", shape=(?,), dtype=int64), required signatures: TensorSignature(dtype=tf.int64, shape=TensorShape([Dimension(None)]), is_sparse=False).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-6adc594028ea> in <module>()
# ----> 1 classifier.fit(X_train, y_train, steps=200, batch_size=20)
#
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     433     result = self._estimator.fit(x=x, y=y, input_fn=input_fn, steps=steps,
#     434                                  batch_size=batch_size, monitors=monitors,
# --> 435                                  max_steps=max_steps)
#     436
#     437     if monitors is not None:
#
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in fit(self, x, y, input_fn, steps, batch_size, monitors, max_steps)
#     331                              steps=steps,
#     332                              monitors=monitors,
# --> 333                              max_steps=max_steps)
#     334     logging.info('Loss for final step: %s.', loss)
#     335     return self
#
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in _train_model(self, input_fn, steps, feed_fn, init_op, init_feed_fn, init_fn, device_fn, monitors, log_every_steps, fail_on_nan_loss, max_steps)
#     660       features, targets = input_fn()
#     661       self._check_inputs(features, targets)
# --> 662       train_op, loss_op = self._get_train_ops(features, targets)
#     663
#     664       # Add default monitors.
#
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in _get_train_ops(self, features, targets)
#     961       Tuple of train `Operation` and loss `Tensor`.
#     962     """
# --> 963     _, loss, train_op = self._call_model_fn(features, targets, ModeKeys.TRAIN)
#     964     return train_op, loss
#     965
#
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in _call_model_fn(self, features, targets, mode)
#     942     if 'mode' in model_fn_args:
#     943       if 'params' in model_fn_args:
# --> 944         return self._model_fn(features, targets, mode=mode, params=self.params)
#     945       else:
#     946         return self._model_fn(features, targets, mode=mode)
#
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py in _dnn_classifier_model_fn(features, targets, mode, params)
#     217         feature_columns=feature_columns,
#     218         weight_collections=[parent_scope],
# --> 219         scope=scope)
#     220
#     221   hidden_layer_partitioner = (
#
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/tensorflow/contrib/layers/python/layers/feature_column_ops.py in input_from_feature_columns(columns_to_tensors, feature_columns, weight_collections, trainable, scope)
#      92     ValueError: if FeatureColumn cannot be consumed by a neural network.
#      93   """
# ---> 94   check_feature_columns(feature_columns)
#      95   with variable_scope.variable_scope(scope,
#      96                                      default_name='input_from_feature_columns',
#
# /Users/abrahamnieto/anaconda/envs/py3/lib/python3.5/site-packages/tensorflow/contrib/layers/python/layers/feature_column_ops.py in check_feature_columns(feature_columns)
#     510   seen_keys = set()
#     511   for f in feature_columns:
# --> 512     key = f.key
#     513     if key in seen_keys:
#     514       raise ValueError('Duplicate feature column key found for column: {}. '
#
# AttributeError: 'str' object has no attribute 'key'

# %%
# Out:
# /Users/marci/anaconda/lib/python3.5/site-packages/tensorflow/python/ops/array_ops.py:1197: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   result_shape.insert(dim, 1)
# DNNClassifier()

# %% [markdown]
# ## Model Evaluation
#
# ** Use the predict method from the classifier model to create predictions from X_test **

# %% [markdown]
# ** Now create a classification report and a Confusion Matrix. Does anything stand out to you?**

# %%
# Out:
# [[237   0]
#  [  1 174]]

# %%
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       237
#           1       1.00      0.99      1.00       175
#
# avg / total       1.00      1.00      1.00       412

# %% [markdown]
# ## Optional Comparison
#
# ** You should have noticed extremely accurate results from the DNN model. Let's compare this to a Random Forest Classifier for a reality check!**
#
# **Use SciKit Learn to Create a Random Forest Classifier and compare the confusion matrix and classification report to the DNN model**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
from sklearn.metrics import classification_report,confusion_matrix
rfc_preds = rfc.predict(X_test)
print(classification_report(y_test,rfc_preds))
print(confusion_matrix(y_test,rfc_preds))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       241
#           1       1.00      1.00      1.00       171
#
# avg / total       1.00      1.00      1.00       412
#
# [[241   0]
#  [  0 171]]

# %%
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.98      0.99       237
#           1       0.98      0.99      0.99       175
#
# avg / total       0.99      0.99      0.99       412

# %%
# Out:
# [[233   4]
#  [  1 174]]

# %% [markdown]
# ** It should have also done very well, but not quite as good as the DNN model. Hopefully you have seen the power of DNN! **

# %% [markdown]
# # Great Job!
